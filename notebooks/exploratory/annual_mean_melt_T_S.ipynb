# %%
# load roms history output as Xarray dataset
import xarray as xr
import matplotlib.pyplot as plt
import os
import sys
import numpy as np

# %%
file_path = os.path.join(os.environ.get('rawdir'),'waom10_v2.0_small','ocean_avg_spinUp_0008.nc')
tides = xr.open_dataset(file_path,chunks={'eta_rho':100,'xi_rho':100}).mean('ocean_time')
file_path = os.path.join(os.environ.get('rawdir'),'waom10_v2.0_small_noTides','ocean_avg_spinUp_0008.nc')
no_tides = xr.open_dataset(file_path,chunks={'eta_rho':100,'xi_rho':100}).mean('ocean_time')
grid_path = os.path.join(os.environ.get('rawdir'),'gdata','waom10_v2.0_frc','waom10_small_grd.nc')
grd = xr.open_dataset(grid_path)

# %%
tides.m.min().values
# Out:
# /home/ubuntu/bigStick/anaconda3/envs/tidal_melting/lib/python3.6/site-packages/dask/array/numpy_compat.py:46: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
# /home/ubuntu/bigStick/anaconda3/envs/tidal_melting/lib/python3.6/site-packages/dask/compatibility.py:47: RuntimeWarning: All-NaN axis encountered
#   return func(*args, **kwargs)
# array(-5.1489416082646976e-08)

# %% [markdown]
# # Melting

# %%
plt.close()
tides.m.plot()
plt.show()
no_tides.m.plot()
plt.show()
(tides.m-no_tides.m).plot()
plt.show()
# Out:
# /home/ubuntu/bigStick/anaconda3/envs/tidal_melting/lib/python3.6/site-packages/dask/array/numpy_compat.py:46: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
out_path =  os.path.join(os.environ.get('rawdir'),'waom10_v2.0_small','ocean_avg_spinUp_0008_mTS.nc')

# %%
out_path =  os.path.join(os.environ.get('rawdir'),'waom10_v2.0_small','ocean_avg_spinUp_0008_mTS.nc')
tides[['m','temp','salt']].to_netcdf(out_path)
# Out:
# /home/ubuntu/bigStick/anaconda3/envs/tidal_melting/lib/python3.6/site-packages/dask/array/numpy_compat.py:46: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
out_path =  os.path.join(os.environ.get('rawdir'),'waom10_v2.0_small_noTides','ocean_avg_spinUp_0008_mTS.nc')
no_tides[['m','temp','salt']].to_netcdf(out_path)
# Out:
# /home/ubuntu/bigStick/anaconda3/envs/tidal_melting/lib/python3.6/site-packages/dask/array/numpy_compat.py:46: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)
